# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
df = pd.read_excel('instant_data.xlsx')

# %%
df.head()
# Out:
#    Review #            Brand                                        Variety  \
# 0      5064    Green & Sunny                              Mee Krob Pad Thai
# 1      5063           Nissin                       Sauce Yakisoba With Soup
# 2      5062         Maruchan  Ramen Noodle Soup Chili Flavor (Prison Ramen)
# 3      5061  Sapporo Ichiban                                     Shio Ramen
# 4      5060            Vifon                    Hoang Gia Spicy Crab Hotpot
#
#   Style        Country Stars   T
# 0  Pack       Thailand     5 NaN
# 1  Tray          Japan     5 NaN
# 2  Pack  United States   3.5 NaN
# 3  Bowl          Japan  3.25 NaN
# 4  Pack        Vietnam     2 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5064 entries, 0 to 5063
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  5064 non-null   int64
#  1   Brand     5064 non-null   object
#  2   Variety   5064 non-null   object
#  3   Style     5064 non-null   object
#  4   Country   5064 non-null   object
#  5   Stars     5061 non-null   object
#  6   T         0 non-null      float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 277.1+ KB

# %%
df.describe()
# Out:
#           Review #    T
# count  5064.000000  0.0
# mean   2532.500000  NaN
# std    1461.995212  NaN
# min       1.000000  NaN
# 25%    1266.750000  NaN
# 50%    2532.500000  NaN
# 75%    3798.250000  NaN
# max    5064.000000  NaN

# %%
df.describe(include='all')
# Out:
#            Review #   Brand     Variety Style Country   Stars    T
# count   5064.000000    5064        5064  5064    5064  5061.0  0.0
# unique          NaN     753        4710    11      57    59.0  NaN
# top             NaN  Nissin  Miso Ramen  Pack   Japan     5.0  NaN
# freq            NaN     615          12  2662    1053  1038.0  NaN
# mean    2532.500000     NaN         NaN   NaN     NaN     NaN  NaN
# std     1461.995212     NaN         NaN   NaN     NaN     NaN  NaN
# min        1.000000     NaN         NaN   NaN     NaN     NaN  NaN
# 25%     1266.750000     NaN         NaN   NaN     NaN     NaN  NaN
# 50%     2532.500000     NaN         NaN   NaN     NaN     NaN  NaN
# 75%     3798.250000     NaN         NaN   NaN     NaN     NaN  NaN
# max     5064.000000     NaN         NaN   NaN     NaN     NaN  NaN
